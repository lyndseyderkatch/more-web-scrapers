# %%
import requests

URL = "https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2380057.m570.l1313&_nkw=kids+nike+size+13&_sacat=0&_pgn=1"
page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html><!--[if IE 9]><html class="ie9 srp-ds6" lang="en"><![endif]--><!--[if gt IE 9]><!--><html class="srp-ds6" lang="en"><!--<![endif]--><!--M#s0-1--><noscript class=x-page-config></noscript><!--M/--><head><meta http-equiv=X-UA-Compatible content=IE=edge><script>"use strict";if(window.PerformanceObserver&&performance&&performance.mark&&performance.getEntriesByName){window.SRP=window.SRP||{};var paintObserver=new window.PerformanceObserver(function(e){var r=e.getEntries();r.sort(function(e,r){return e.startTime-r.startTime});var n=r[1].startTime;window.SRP.TTI_TIMER={lastInteractiveWindow:n};var t=new window.PerformanceObserver(function(e){for(var r=e.getEntries(),i=0,a=r.length;i<a;i++)r[i].startTime-n>=5e3&&(window.SRP.TTI_TIMER.timeToInteract=n,t.disconnect()),n=r[i].startTime+r[i].duration,window.SRP.TTI_TIMER.lastInteractiveWindow=n});t.observe({entryTypes:["longtask"]}),paintObserver.disconnect()});paintObserver.observe({entryTypes:["paint"]})};</script><title>kids nik
# ...

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2380057.m570.l1313&_nkw=kids+nike+size+13&_sacat=0&_pgn=1"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find_all('span', class_='s-item__price')

# %%
print(results)
# Out:
# [<span class="s-item__price">$20.00</span>, <span class="s-item__price">$24.99</span>, <span class="s-item__price">$49.95</span>, <span class="s-item__price">$13.45</span>, <span class="s-item__price">$34.95</span>, <span class="s-item__price">$10.00</span>, <span class="s-item__price">$20.00</span>, <span class="s-item__price">$15.00</span>, <span class="s-item__price">$21.00</span>, <span class="s-item__price">$35.00</span>, <span class="s-item__price">$23.00</span>, <span class="s-item__price">$12.99</span>, <span class="s-item__price">$20.00</span>, <span class="s-item__price">$9.99</span>, <span class="s-item__price">$18.00</span>, <span class="s-item__price">$5.00</span>, <span class="s-item__price">$25.00</span>, <span class="s-item__price">$20.00</span>, <span class="s-item__price">$10.00</span>, <span class="s-item__price">$29.99</span>, <span class="s-item__price">$19.00</span>, <span class="s-item__price">$27.00</span>, <span class="s-item__price">$14.99</span>, <span clas
# ...

# %%
#print(results.prettify())

# %%
#price_elements = results.find_all("span", class_="s-item__price")

# %%
#print(price_elements)

# %%
for price_element in results:
    price = price_element.find("span", class_="s-item_price")
    print(price_element.text.strip())
    print()
# Out:
# $20.00
#
# $24.99
#
# $49.95
#
# $13.45
#
# $34.95
#
# $10.00
#
# $20.00
#
# $15.00
#
# $21.00
#
# $35.00
#
# $23.00
#
# $12.99
#
# $20.00
#
# $9.99
#
# $18.00
#
# $5.00
#
# $25.00
#
# $20.00
#
# $10.00
#
# $29.99
#
# $19.00
#
# $27.00
#
# $14.99
#
# $9.99
#
# $24.99
#
# $29.99
#
# $10.50
#
# $21.90
#
# $20.99
#
# $20.00
#
# $8.00
#
# $35.00
#
# $46.00
#
# $39.99
#
# $55.00
#
# $90.00
#
# $15.00
#
# $23.50
#
# $10.00
#
# $55.00
#
# $0.99
#
# $5.00
#
# $25.00
#
# $20.00
#
# $36.00
#
# $27.00
#
# $40.00
#
# $40.00
#
# $9.80
#
# $54.95
#
# $27.00
#
# $29.99
#
# $12.38
#
# $26.00
#
# $19.99
#
# $9.90
#
# $11.00
#
# $20.00
#
# $24.47
#
# $19.99
#
# $34.99
#
# $13.90
#
# $10.00
#
# $24.99
#
# $32.99
#
# $39.99
#
# $24.99
#
# $20.50
#
# $45.00
#
# $12.40
#
# $29.00
#
# $26.20
#
# $15.00
#
# $27.00
#
# $22.99
#
# $19.50
#
# $44.00
#
# $19.99
#
# $13.00
